# %%
import pandas as pd
import json
import os

# %%
with open('result.json') as user_file:
  file_contents = json.load(user_file)

# %%
file_contents
# Out:
# {'CHRG-110shrg40884_186': None,
#  'CHRG-111hhrg78126_153': None,
#  'CHRG-110hhrg45067_85': None,
#  'CHRG-110hhrg38334_141': None,
#  'CHRG-116hhrg44864_228': None,
#  'CHRG-114hhrg22783_127': None,
#  'CHRG-109hhrg99773_71': None,
#  'CHRG-114shrg21993_130': None,
#  'CHRG-112shrg67119_72': None,
#  'CHRG-111hhrg54863_249': None,
#  'CHRG-110hhrg42525_17': None,
#  'CHRG-113hhrg82640_256': None,
#  'CHRG-113hhrg88719_75': None,
#  'CHRG-109hhrg35426_160': None,
#  'CHRG-115shrg30137_33': None,
#  'CHRG-116hhrg36619_249': None,
#  'CHRG-114hhrg99855_155': None,
#  'CHRG-110shrg34416_117': None,
#  'CHRG-116hhrg36565_30': None,
#  'CHRG-108hhrg92616_43': None,
#  'CHRG-109hhrg23703_144': None,
#  'CHRG-114hhrg95228_54': None,
#  'CHRG-114hhrg24915_58': None,
#  'CHRG-111hhrg48875_11': None,
#  'CHRG-112hhrg71401_102': None,
#  'CHRG-111hhrg55480_168': None,
#  'CHRG-112hhrg74404_293': None,
#  'CHRG-109shrg42273_90': None,
#  'CHRG-114hhrg23641_27': None,
# ...

# %%
for element in file_contents:
    if file_contents[element] is not None:
        print(element)

# %%
len(file_contents)
# Out:
# 499896
